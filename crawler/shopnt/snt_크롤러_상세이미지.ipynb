# %%
# Using readline() 
file1 = open('snt_url.txt', 'r') 
count = 0
  
while True: 
    count += 1
  
    # Get next line from file 
    line = file1.readline() 
  
    # if line is empty 
    # end of file is reached 
    if not line: 
        break
    print("Line{}: {}".format(count, line.strip())) 
  
file1.close()
# Out:
# Line1: http://www.shoppingntmall.com/display/goods/10095285
# Line2: http://www.shoppingntmall.com/display/goods/10150400
# Line3: http://www.shoppingntmall.com/display/goods/10101952
# Line4: http://www.shoppingntmall.com/display/goods/10090357
# Line5: http://www.shoppingntmall.com/display/goods/10094475
# Line6: http://www.shoppingntmall.com/display/goods/10099720
# Line7: http://www.shoppingntmall.com/display/goods/10096064
# Line8: http://www.shoppingntmall.com/display/goods/10099248
# Line9: http://www.shoppingntmall.com/display/goods/10168306
# Line10: http://www.shoppingntmall.com/display/goods/10087911
# Line11: http://www.shoppingntmall.com/display/goods/10099536
# Line12: http://www.shoppingntmall.com/display/goods/10094573
# Line13: http://www.shoppingntmall.com/display/goods/10097573
# Line14: http://www.shoppingntmall.com/display/goods/10104800
# Line15: http://www.shoppingntmall.com/display/goods/10096058
# Line16: http://www.shoppingntmall.com/display/goods/10089913
# ...

# %%
## BeautifulSoup 참고문서
## https://www.crummy.com/software/BeautifulSoup/bs4/doc.ko/
import requests
from selenium import webdriver
from bs4 import BeautifulSoup
from time import sleep

base_url = "http://www.shoppingntmall.com/display/goods/"
#url = "http://www.shoppingntmall.com/display/goods/10288949"

def get_cpf(new_url):
    #print(url_)
    driver = webdriver.Chrome("./chromedriver")
    #response = requests.get(contents_in_url + path_to_add_to_url)
    driver.get(new_url)
    10289178
    # html source 추출 
    sleep(3)
    html_source = driver.page_source # BS로 html parsing
    soup = BeautifulSoup(html_source, 'html.parser') 
    
    soup = BeautifulSoup(html_doc)

    print(soup.prettify())

    goods = soup.find(id="goods_describe")
    if goods is None:
        return
    one_detail_images=[]
    one_detail_images.append(produce_code)
    for img in goods.find_all('img'):
        if  "banner" in img['src']:
            continue
        if "top" in img['src']:
            continue
        if "bottom" in img['src']:
            continue
        if img['src'].endswith(".gif"):
            continue
        one_detail_images.append(img['src'])
    print(one_detail_images)
    
#file1 = open('product_code.txt', 'r') 
file1 = open('snt_url.txt', 'r') 
# = fp.read()
#u = s.decode("utf-8-sig")
count = 0
#while True: 
while (count != 1):     
    count += 1
  
    # Get next line from file 
    line = file1.readline()
    # if line is empty 
    # end of file is reached 
    if not line: 
        break
    detail_link = line.strip()
    #print("Line{}: {}".format(count, line.strip())) 
    #url = base_url+prod_code
    #url = detail_link
    produce_code = detail_link[43:51]
    print(produce_code)
    #print(base_url)
    #print(base_url+produce_code)
    get_cpf(detail_link)
# Out:
# /1009528
# ['/1009528', 'http://img.shoppingntmall.com/htmleditor/812/%EC%97%AC%EC%84%B1%EB%B3%B4%EC%9D%B4%ED%95%8F%EB%8D%B0%EB%8B%982%EC%A2%851573538765535.jpg']

# %%
#### 대분류 소분류 추출
import time

from selenium import webdriver
from selenium.webdriver.common.keys import Keys

driver = webdriver.Chrome('./chromedriver') 
# target page 접근 
driver.get("http://www.shoppingntmall.com/category/g-list-cate/20000049")

SCROLL_PAUSE_TIME = 0.5

# Get scroll height
last_height = driver.execute_script("return document.body.scrollHeight")

while True:
    # Scroll down to bottom
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

    # Wait to load page
    time.sleep(SCROLL_PAUSE_TIME)

    # Calculate new scroll height and compare with last scroll height
    new_height = driver.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height

# html source 추출 
html_source = driver.page_source # BS로 html parsing 
soup = BeautifulSoup(html_source, 'html.parser') 
title = soup.select('.goods_detail span')

for product in soup.select('.sc_pro li a'):
    product_code = product.get('href')[33:41]
    for img in product.find_all('img', alt=True):
        print(product_code,'$"',img['alt'],'"$"',img['src'],'"$')
#products = soup.select('.sc_pro li a')
#prod_cd = [[product.get('img')['alt']] for product in products]
#prod_cd = [[product.get('href')[33:41], product.find('img')['alt']] for product in products]
#print(prod_cd)
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-95-abb3b865498a> in <module>
#      22
#      23     # Calculate new scroll height and compare with last scroll height
# ---> 24     new_height = driver.execute_script("return document.body.scrollHeight")
#      25     if new_height == last_height:
#      26         break
#
# ~/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in execute_script(self, script, *args)
#     632             command = Command.EXECUTE_SCRIPT
#     633
# --> 634         return self.execute(command, {
#     635             'script': script,
#     636             'args': converted_args})['value']
#
# ~/anaconda3/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
# ...
